# %%
import os 
import random 
import shutil 
train_path = "data/train"
test_path = "data/test"
species_list = os.listdir(train_path) 
split_ratio = 0.25

# %%
# for species in species_list:
#     images_list = os.listdir(train_path + "/" + species)
#     images_total = len(images_list) 
#     test_images = random.sample(images_list, int(split_ratio * images_total)) 
#     # move the images to test
#     for image in test_images: 
#         source = train_path + "/" + species + "/" + image 
#         destination = test_path + "/" + species 
#         shutil.move(source, destination)

# %%
# check the moving procedure
for species in species_list:
    train_images_total = len(os.listdir(train_path + "/" + species))
    test_images_total = len(os.listdir(test_path + "/" + species)) 
    print(train_images_total, test_images_total)
    print(test_images_total/(train_images_total + test_images_total))
# Out:
# 130 43
# 0.24855491329479767
# 143 47
# 0.24736842105263157
# 129 42
# 0.24561403508771928
# 142 47
# 0.24867724867724866
# 109 36
# 0.2482758620689655
# 123 41
# 0.25
# 111 36
# 0.24489795918367346
# 124 41
# 0.24848484848484848
# 148 49
# 0.24873096446700507
# 142 47
# 0.24867724867724866
# 107 35
# 0.24647887323943662
# 132 43
# 0.24571428571428572
# 132 44
# 0.25
# 120 40
# 0.25
# 142 47
# 0.24867724867724866
# 135 45
# 0.25
# 126 42
# 0.25
# 153 50
# 0.24630541871921183
# 131 43
# 0.2471264367816092
# 108 35
# 0.24475524475524477
# 124 41
# 0.24848484848484848
# 142 47
# 0.24867724867724866
# 112 37
# 0.2483221476510067
# 118 39
# 0.2484076433121019
# 148 49
# 0.24873096446700507
# 105 35
# 0.25
# 108 36
# 0.25
# 116 38
# 0.24675324675324675
# 123 41
# 0.25
# 123 40
# 0.24539877300613497
# 120 40
# 0.25
# 112 37
# 0.2483221476510067
# 120 40
# 0.25
# 112 37
# 0.2483221476510067
# 123 41
# 0.25
# 123 40
# 0.24539877300613497
# 122 40
# 0.24691358024691357
# 149 49
# ...
